# %% [markdown]
# <a href="https://colab.research.google.com/github/SUSHMA1436/fmml-lab/blob/main/Module_7_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Module 7 Project: Movie Recommendation Engine

# %% [markdown]
# `Module Coordinator: Ganesh Chandan`

# %% [markdown]
# In this module, we will try to create a Movie Recommendation System using different unsupervised learning techniques.

# %%
# dataset download

# !wget https://files.grouplens.org/datasets/movielens/ml-100k.zip
# !wget https://files.grouplens.org/datasets/movielens/ml-latest-small.zip
# !unzip ml-latest-small.zip
# Out:
# --2024-02-24 16:47:56--  https://files.grouplens.org/datasets/movielens/ml-latest-small.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 978202 (955K) [application/zip]
# Saving to: ‘ml-latest-small.zip.3’
#
# ml-latest-small.zip 100%[===================>] 955.28K  --.-KB/s    in 0.1s
#
# 2024-02-24 16:47:56 (8.28 MB/s) - ‘ml-latest-small.zip.3’ saved [978202/978202]
#
# Archive:  ml-latest-small.zip
# replace ml-latest-small/links.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# ## Clustering based recommendation

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.sparse import csr_matrix
from mpl_toolkits.axes_grid1 import make_axes_locatable
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error
import itertools
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
# Import the Movies dataset
movies = pd.read_csv('ml-latest-small/movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Import the ratings dataset
ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
# Print the number of records and the total number of movies
print('The dataset contains: ', len(ratings), ' ratings of ', len(movies), ' movies.')
# Out:
# The dataset contains:  100836  ratings of  9742  movies.

# %% [markdown]
# ### Romance versus Science Fiction
#
# We will start by considering a subset of users and discovering what are their favourite genre. We will do this by defining a function that will calculate each user’s average rating for all science fiction and romance movies.

# %%
# Function to get the genre ratings
def get_genre_ratings(ratings, movies, genres, column_names):
    genre_ratings = pd.DataFrame()
    for genre in genres:
        genre_movies = movies[movies['genres'].str.contains(genre) ]
        avg_genre_votes_per_user = ratings[ratings['movieId'].isin(genre_movies['movieId'])].loc[:, ['userId', 'rating']].groupby(['userId'])['rating'].mean().round(2)

        genre_ratings = pd.concat([genre_ratings, avg_genre_votes_per_user], axis=1)

    genre_ratings.columns = column_names
    return genre_ratings# Calculate the average rating of romance and scifi movies
genre_ratings = get_genre_ratings(ratings, movies, ['Romance', 'Sci-Fi'], ['avg_romance_rating', 'avg_scifi_rating'])
genre_ratings.head()
# Out:
#    avg_romance_rating  avg_scifi_rating
# 1                4.31              4.22
# 2                4.50              3.88
# 3                0.50              4.20
# 4                3.38              2.83
# 5                3.09              2.50

# %% [markdown]
# In order to have a more delimited subset of people to study, we are going to bias our grouping to only get ratings from those users that like either romance or science fiction movies.

# %%
# Function to get the biased dataset
def bias_genre_rating_dataset(genre_ratings, score_limit_1, score_limit_2):
    biased_dataset =    genre_ratings[((genre_ratings['avg_romance_rating'] < score_limit_1 - 0.2) & (genre_ratings['avg_scifi_rating'] > score_limit_2)) | ((genre_ratings['avg_scifi_rating'] < score_limit_1) & (genre_ratings['avg_romance_rating'] > score_limit_2))]
    biased_dataset = pd.concat([biased_dataset[:300], genre_ratings[:2]])
    biased_dataset = pd.DataFrame(biased_dataset.to_records())
    return biased_dataset

# Bias the dataset
biased_dataset = bias_genre_rating_dataset(genre_ratings, 3.2, 2.5)

# Printing the resulting number of records & the head of the dataset
print( "Number of records: ", len(biased_dataset))
biased_dataset.head()
# Out:
# Number of records:  162
#    index  avg_romance_rating  avg_scifi_rating
# 0      3                0.50              4.20
# 1      4                3.38              2.83
# 2      5                3.09              2.50
# 3      7                2.65              3.15
# 4      9                3.17              3.00

# %%
# Defining the scatterplot drawing function
def draw_scatterplot(x_data, x_label, y_data, y_label):
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(111)
    plt.xlim(0, 5)
    plt.ylim(0, 5)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.scatter(x_data, y_data, s=30)

# Plot the scatterplot
draw_scatterplot(biased_dataset['avg_scifi_rating'],'Avg scifi rating', biased_dataset['avg_romance_rating'], 'Avg romance rating')

# %%
# Let's turn our dataset into a list
X = biased_dataset[['avg_scifi_rating','avg_romance_rating']].values

# Import KMeans
from sklearn.cluster import KMeans

# Create an instance of KMeans to find two clusters
kmeans_1 = KMeans(n_clusters=2)

# Use fit_predict to cluster the dataset
predictions = kmeans_1.fit_predict(X)

# Defining the cluster plotting function
def draw_clusters(biased_dataset, predictions, cmap='viridis'):
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(111)
    plt.xlim(0, 5)
    plt.ylim(0, 5)
    ax.set_xlabel('Avg scifi rating')
    ax.set_ylabel('Avg romance rating')
    clustered = pd.concat([biased_dataset.reset_index(), pd.DataFrame({'group':predictions})], axis=1)
    plt.scatter(clustered['avg_scifi_rating'], clustered['avg_romance_rating'], c=clustered['group'], s=20, cmap=cmap)

# Plot
draw_clusters(biased_dataset, predictions)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Create an instance of KMeans to find three clusters
kmeans_2 = KMeans(n_clusters=3)
# Use fit_predict to cluster the dataset
predictions_2 = kmeans_2.fit_predict(X)
# Plot
draw_clusters(biased_dataset, predictions_2)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# It is evident now that the science-fiction rating has started to come into play:
#
#     People who like sci-fi and romance modeately belong to the green group.
#     People who like scifi but not romance belong to the yello group.
#     People who like romance but not sci-fi belong to the purple group.

# %% [markdown]
# Finding optimal clusters using silhouette score

# %%
# Selecting our dataset to study
df = biased_dataset[['avg_scifi_rating','avg_romance_rating']]

# Choose the range of k values to test.
# We added a stride of 5 to improve performance. We don't need to calculate the error for every k value
possible_k_values = range(2, len(X)+1, 5)

# Define function to calculate the clustering errors
def clustering_errors(k, data):
    kmeans = KMeans(n_clusters=k).fit(data)
    predictions = kmeans.predict(data)
    #cluster_centers = kmeans.cluster_centers_
    # errors = [mean_squared_error(row, cluster_centers[cluster]) for row, cluster in zip(data.values, predictions)]
    # return sum(errors)
    silhouette_avg = silhouette_score(data, predictions)
    return silhouette_avg

# Calculate error values for all k values we're interested in
errors_per_k = [clustering_errors(k, X) for k in possible_k_values]

# Plot the each value of K vs. the silhouette score at that value
fig, ax = plt.subplots(figsize=(16, 6))
plt.plot(possible_k_values, errors_per_k)

# Ticks and grid
xticks = np.arange(min(possible_k_values), max(possible_k_values)+1, 5.0)
ax.set_xticks(xticks, minor=False)
ax.set_xticks(xticks, minor=True)
ax.xaxis.grid(True, which='both')
yticks = np.arange(round(min(errors_per_k), 2), max(errors_per_k), .05)
ax.set_yticks(yticks, minor=False)
ax.set_yticks(yticks, minor=True)
ax.yaxis.grid(True, which='both')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-184-ea56d5ac5a15>:10: ConvergenceWarning: Number of distinct clusters (157) found smaller than n_clusters (162). Possibly due to duplicate points in X.
#   kmeans = KMeans(n_clusters=k).fit(data)

# %% [markdown]
# We will chose the K = 7 as it is the one that yields the best score and will be easier to visualize.

# %%
# Create an instance of KMeans to find seven clusters
kmeans_4 = KMeans(n_clusters=7)
# Use fit_predict to cluster the dataset
predictions_4 = kmeans_4.fit_predict(X)
# Plot
draw_clusters(biased_dataset, predictions_4, cmap='Accent')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Up to now, we have only analyzed romance and science-fiction movies. Let us see what happens when adding other genre to our analysis by adding Action movies.

# %%
# Select our biased dataset and add action genre
biased_dataset_3_genres = get_genre_ratings(ratings, movies, ['Romance','Sci-Fi', 'Action'],
['avg_romance_rating', 'avg_scifi_rating', 'avg_action_rating'])
# Drop null values
biased_dataset_3_genres = bias_genre_rating_dataset(biased_dataset_3_genres, 3.2, 2.5).dropna()
# Print the number of records and the head of our dataset
print( "Number of records: ", len(biased_dataset_3_genres))
biased_dataset_3_genres.head()
# Out:
# Number of records:  161
#    index  avg_romance_rating  avg_scifi_rating  avg_action_rating
# 0      3                0.50              4.20               3.57
# 1      4                3.38              2.83               3.32
# 2      5                3.09              2.50               3.11
# 3      7                2.65              3.15               3.26
# 4      9                3.17              3.00               3.12

# %%
# Turn dataset into a list
X_with_action = biased_dataset_3_genres[['avg_scifi_rating','avg_romance_rating','avg_action_rating']].values# Create an instance of KMeans to find seven clusters
kmeans_5 = KMeans(n_clusters=7)
# Use fit_predict to cluster the dataset
predictions_5 = kmeans_5.fit_predict(X_with_action)
# Define 3d plotting function
def draw_clusters_3d(biased_dataset_3, predictions):
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(111)
    plt.xlim(0, 5)
    plt.ylim(0, 5)
    ax.set_xlabel('Avg scifi rating')
    ax.set_ylabel('Avg romance rating')
    clustered = pd.concat([biased_dataset_3.reset_index(), pd.DataFrame({'group':predictions})], axis=1)
    colors = itertools.cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])
    for g in clustered.group.unique():
        color = next(colors)
        for index, point in clustered[clustered.group == g].iterrows():
            if point['avg_action_rating'].astype(float) > 3:
                size = 50
            else:
                size = 15
            plt.scatter(point['avg_scifi_rating'],
                        point['avg_romance_rating'],
                        s=size,
                        color=color)# Plot
draw_clusters_3d(biased_dataset_3_genres, predictions_5)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# The size of the dots represent the ratings of the action movies.

# %% [markdown]
# # Exercise 1
#
# ## Instead of choosing a n_clusters as 7, play around with different k
# ## Find the optimal no of clusters with 3 genre_ratings data we just created using silhouette score method

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')

genre_ratings_imputed = imputer.fit_transform(genre_ratings)

silhouette_scores = []

for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(genre_ratings_imputed)
    silhouette_avg = silhouette_score(genre_ratings_imputed, kmeans.labels_)
    silhouette_scores.append((k, silhouette_avg))

best_k, best_silhouette_score = max(silhouette_scores, key=lambda x: x[1])

print(f"The optimal number of clusters is: {best_k} with a silhouette score of {best_silhouette_score}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# The optimal number of clusters is: 2 with a silhouette score of 0.402772563719914

# %% [markdown]
# ### Taking users into consideration

# %% [markdown]
# Once we have seen and understood how the K-Means algorithm group the users by their movie genre preferences, we are going to take a bigger picture of the dataset and explore how users rate individual movies.
#
# To do so, we will subset the dataset by ‘userid’ vs ‘user rating’ as follows.

# %%
# Merge the two tables then pivot so we have Users X Movies dataframe
ratings_title = pd.merge(ratings, movies[['movieId', 'title']], on='movieId' )
user_movie_ratings = pd.pivot_table(ratings_title, index='userId', columns= 'title', values='rating')

# Print he number of dimensions and a subset of the dataset
print('dataset dimensions: ', user_movie_ratings.shape, '\n\nSubset example:')
user_movie_ratings.iloc[:6, :10]
# Out:
# dataset dimensions:  (610, 9719)
#
# Subset example:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
# 6              NaN                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# 5                          NaN                  NaN
# 6                          NaN                  NaN
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# 6                             NaN                              NaN
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 1                      NaN                   NaN                          NaN
# 2                      NaN                   NaN                          NaN
# 3                      NaN                   NaN                          NaN
# 4                      NaN                   NaN                          NaN
# 5                      NaN                   NaN                          NaN
# 6                      NaN                   NaN                          NaN
#
# title   *batteries not included (1987)
# userId
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN

# %%
# Define Function to get the most rated movies
def get_most_rated_movies(user_movie_ratings, max_number_of_movies):
    # 1- Count
    user_movie_ratings = user_movie_ratings.append(user_movie_ratings.count(), ignore_index=True)
    # 2- sort
    user_movie_ratings_sorted = user_movie_ratings.sort_values(len(user_movie_ratings)-1, axis=1, ascending=False)
    user_movie_ratings_sorted = user_movie_ratings_sorted.drop(user_movie_ratings_sorted.tail(1).index)
    # 3- slice
    most_rated_movies = user_movie_ratings_sorted.iloc[:, :max_number_of_movies]
    return most_rated_movies

# Define function to get the user who rate a movie the most
def get_users_who_rate_the_most(most_rated_movies, n_users):
    most_rated_movies['num_ratings'] = - most_rated_movies.isnull().sum(axis=1)
    most_rated_movies = most_rated_movies.sort_values(by=['num_ratings'], ascending=False)
    most_rated_movies = most_rated_movies.iloc[:n_users, :]
    most_rated_movies = most_rated_movies.drop('num_ratings', axis=1)
    return most_rated_movies

# Define the sorting by rating function
def sort_by_rating_density(user_movie_ratings, n_movies, n_users):
    most_rated_movies = get_most_rated_movies(user_movie_ratings, n_movies)
    most_rated_movies = get_users_who_rate_the_most(most_rated_movies, n_users)
    return most_rated_movies

# choose the number of movies and users and sort
n_movies = 30
n_users = 18
most_rated_movies_users_selection = sort_by_rating_density(user_movie_ratings, n_movies, n_users)

# Print the result
# print(most_rated_movies_users_selection)
print('dataset dimensions: ', most_rated_movies_users_selection.shape)
print(most_rated_movies_users_selection.head())
# Out:
# dataset dimensions:  (18, 30)
# title  Forrest Gump (1994)  Shawshank Redemption, The (1994)  \
# 413                    5.0                               5.0
# 589                    5.0                               4.5
# 473                    3.0                               5.0
# 479                    5.0                               5.0
# 67                     3.5                               3.0
#
# title  Pulp Fiction (1994)  Silence of the Lambs, The (1991)  \
# 413                    5.0                               4.0
# 589                    4.5                               3.5
# 473                    4.0                               4.5
# 479                    4.0                               4.5
# 67                     2.0                               3.5
#
# title  Matrix, The (1999)  Star Wars: Episode IV - A New Hope (1977)  \
# 413                   5.0                                        5.0
# 589                   4.0                                        5.0
# 473                   4.5                                        4.0
# 479                   5.0                                        4.5
# 67                    4.5                                        5.0
#
# title  Jurassic Park (1993)  Braveheart (1995)  \
# 413                     4.0                5.0
# 589                     4.0                4.0
# 473                     4.5                3.0
# 479                     5.0                5.0
# 67                      3.5                2.5
#
# title  Terminator 2: Judgment Day (1991)  Schindler's List (1993)  ...  \
# 413                                  5.0                      4.0  ...
# 589                                  4.5                      5.0  ...
# 473                                  4.0                      5.0  ...
# 479                                  4.5                      5.0  ...
# 67                                   3.5                      4.0  ...
#
# title  Star Wars: Episode VI - Return of the Jedi (1983)  \
# 413                                                  5.0
# 589                                                  4.5
# 473                                                  4.0
# 479                                                  3.5
# 67                                                   5.0
#
# title  Godfather, The (1972)  Fugitive, The (1993)  Batman (1989)  \
# 413                      5.0                   5.0            4.0
# 589                      5.0                   4.0            3.5
# 473                      5.0                   5.0            4.0
# 479                      5.0                   3.5            4.5
# 67                       4.0                   4.5            4.0
#
# title  Saving Private Ryan (1998)  \
# 413                           5.0
# 589                           4.0
# 473                           3.0
# 479                           4.5
# 67                            4.0
#
# title  Lord of the Rings: The Two Towers, The (2002)  \
# 413                                              5.0
# 589                                              5.0
# 473                                              5.0
# 479                                              4.5
# 67                                               4.0
#
# title  Lord of the Rings: The Return of the King, The (2003)  Aladdin (1992)  \
# 413                                                      4.0             4.0
# 589                                                      4.5             4.0
# 473                                                      5.0             4.0
# 479                                                      4.0             4.0
# 67                                                       4.5             3.5
#
# title  Fargo (1996)  Sixth Sense, The (1999)
# 413             5.0                      3.0
# 589             4.0                      3.5
# 473             4.0                      5.0
# 479             4.0                      4.0
# 67              2.5                      2.5
#
# [5 rows x 30 columns]
# <ipython-input-190-0b2c7ceec495>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   user_movie_ratings = user_movie_ratings.append(user_movie_ratings.count(), ignore_index=True)

# %%
# Define the plotting heatmap function
def draw_movies_heatmap(most_rated_movies_users_selection, axis_labels=True):

    fig = plt.figure(figsize=(15,4))
    ax = plt.gca()

    # Draw heatmap
    heatmap = ax.imshow(most_rated_movies_users_selection,  interpolation='nearest', vmin=0, vmax=5, aspect='auto')
    if axis_labels:
        ax.set_yticks(np.arange(most_rated_movies_users_selection.shape[0]) , minor=False)
        ax.set_xticks(np.arange(most_rated_movies_users_selection.shape[1]) , minor=False)
        ax.invert_yaxis()
        ax.xaxis.tick_top()
        labels = most_rated_movies_users_selection.columns.str[:40]
        ax.set_xticklabels(labels, minor=False)
        ax.set_yticklabels(most_rated_movies_users_selection.index, minor=False)
        plt.setp(ax.get_xticklabels(), rotation=90)
    else:
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    ax.grid(False)
    ax.set_ylabel('User id')# Separate heatmap from color bar
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)# Color bar
    cbar = fig.colorbar(heatmap, ticks=[5, 4, 3, 2, 1, 0], cax=cax)
    cbar.ax.set_yticklabels(['5 stars', '4 stars','3 stars','2 stars','1 stars','0 stars'])
    plt.show()# Print the heatmap
draw_movies_heatmap(most_rated_movies_users_selection)

# %%
# Pivot the dataset and choose the first 1000 movies
user_movie_ratings =  pd.pivot_table(ratings_title, index='userId', columns= 'title', values='rating')
most_rated_movies_1k = get_most_rated_movies(user_movie_ratings, 1000).replace(np.nan, 0)
# Out:
# <ipython-input-190-0b2c7ceec495>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   user_movie_ratings = user_movie_ratings.append(user_movie_ratings.count(), ignore_index=True)

# %%
from scipy import sparse

# Conversion to sparse csr matrix
sparse_ratings = sparse.csr_matrix(most_rated_movies_1k.values)

# %% [markdown]
# ### Large Scale Clustering

# %%
# 20 clusters
predictions = KMeans(n_clusters=20, algorithm='full').fit_predict(sparse_ratings)
# Select the mas number of users and movies heatmap cluster
# Cluster and print some of them
clustered = pd.concat([get_most_rated_movies(user_movie_ratings, 1000).reset_index(), pd.DataFrame({'group':predictions})], axis=1)
# draw_movie_clusters(clustered, max_users, max_movies)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1366: FutureWarning: algorithm='full' is deprecated, it will be removed in 1.3. Using 'lloyd' instead.
#   warnings.warn(
# <ipython-input-190-0b2c7ceec495>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   user_movie_ratings = user_movie_ratings.append(user_movie_ratings.count(), ignore_index=True)

# %% [markdown]
# ### Predictions and Recommendation

# %%
# Pick a cluster ID from the clusters above
cluster_number = 11
# Let's filter to only see the region of the dataset with the most number of values
n_users = 75
n_movies = 300
cluster = clustered[clustered.group == cluster_number].drop(['index', 'group'], axis=1)
print(cluster)
# Sort and print the cluster
cluster = sort_by_rating_density(cluster, n_movies, n_users)
draw_movies_heatmap(cluster, axis_labels=False)
# Out:
# <ipython-input-190-0b2c7ceec495>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   user_movie_ratings = user_movie_ratings.append(user_movie_ratings.count(), ignore_index=True)
#      Forrest Gump (1994)  Shawshank Redemption, The (1994)  \
# 27                   4.0                               3.5
# 44                   5.0                               NaN
# 65                   5.0                               4.5
# 90                   3.0                               2.0
# 139                  4.0                               4.0
# 159                  3.0                               NaN
# 165                  4.0                               4.5
# 197                  5.0                               5.0
# 219                  5.0                               5.0
# 238                  5.0                               5.0
# 329                  5.0                               4.5
# 353                  4.5                               4.5
# 356                  3.5                               4.0
# 390                  5.0                               5.0
# 424                  5.0                               5.0
# 433                  4.5                               4.0
# 569                  4.0                               4.0
# 579                  4.0                               5.0
#
#      Pulp Fiction (1994)  Silence of the Lambs, The (1991)  \
# 27                   4.5                               2.5
# 44                   5.0                               4.0
# 65                   5.0                               4.0
# 90                   4.5                               4.5
# 139                  4.0                               4.0
# 159                  5.0                               2.0
# 165                  4.5                               4.0
# 197                  5.0                               4.0
# 219                  5.0                               NaN
# 238                  5.0                               3.5
# 329                  4.0                               5.0
# 353                  4.5                               4.0
# 356                  4.5                               4.5
# 390                  5.0                               3.0
# 424                  4.0                               4.0
# 433                  5.0                               4.0
# 569                  NaN                               NaN
# 579                  5.0                               4.5
#
#      Matrix, The (1999)  Star Wars: Episode IV - A New Hope (1977)  \
# 27                  4.0                                        4.0
# 44                  5.0                                        5.0
# 65                  5.0                                        2.5
# 90                  5.0                                        4.5
# 139                 4.0                                        4.0
# 159                 4.0                                        5.0
# 165                 4.0                                        4.5
# 197                 5.0                                        5.0
# 219                 5.0                                        5.0
# 238                 5.0                                        5.0
# 329                 3.5                                        4.0
# 353                 4.0                                        4.0
# 356                 NaN                                        4.0
# 390                 5.0                                        5.0
# 424                 3.5                                        3.0
# 433                 5.0                                        5.0
# 569                 4.5                                        3.5
# 579                 5.0                                        4.0
#
#      Jurassic Park (1993)  Braveheart (1995)  \
# 27                    2.5                3.5
# 44                    4.0                5.0
# 65                    3.0                5.0
# 90                    4.5                4.0
# 139                   4.0                4.0
# 159                   2.0                4.0
# 165                   NaN                NaN
# 197                   3.0                3.0
# 219                   5.0                NaN
# 238                   4.0                4.5
# 329                   2.0                3.5
# 353                   4.0                NaN
# 356                   4.0                4.0
# 390                   2.0                5.0
# 424                   3.5                4.0
# 433                   5.0                4.5
# 569                   NaN                3.5
# 579                   4.0                4.5
#
#      Terminator 2: Judgment Day (1991)  Schindler's List (1993)  ...  \
# 27                                 4.5                      3.0  ...
# 44                                 5.0                      NaN  ...
# 65                                 4.0                      NaN  ...
# 90                                 4.0                      NaN  ...
# 139                                NaN                      5.0  ...
# 159                                5.0                      5.0  ...
# 165                                NaN                      4.5  ...
# 197                                3.0                      NaN  ...
# 219                                5.0                      NaN  ...
# 238                                3.5                      NaN  ...
# 329                                3.5                      NaN  ...
# 353                                4.5                      4.0  ...
# 356                                3.5                      5.0  ...
# 390                                4.0                      5.0  ...
# 424                                3.5                      4.0  ...
# 433                                4.5                      5.0  ...
# 569                                4.0                      4.5  ...
# 579                                4.0                      3.0  ...
#
#      Scary Movie 2 (2001)  About Schmidt (2002)  21 Jump Street (2012)  \
# 27                    NaN                   3.0                    NaN
# 44                    NaN                   NaN                    NaN
# 65                    NaN                   NaN                    NaN
# 90                    NaN                   NaN                    NaN
# 139                   NaN                   3.0                    NaN
# 159                   NaN                   NaN                    NaN
# 165                   NaN                   NaN                    NaN
# 197                   1.0                   NaN                    NaN
# 219                   NaN                   NaN                    NaN
# 238                   NaN                   NaN                    NaN
# 329                   NaN                   NaN                    NaN
# 353                   NaN                   NaN                    NaN
# 356                   NaN                   NaN                    NaN
# 390                   NaN                   NaN                    NaN
# 424                   NaN                   NaN                    NaN
# 433                   NaN                   NaN                    NaN
# 569                   NaN                   NaN                    NaN
# 579                   NaN                   NaN                    NaN
#
#      Cider House Rules, The (1999)  Death Proof (2007)  Moonraker (1979)  \
# 27                             NaN                 NaN               NaN
# 44                             NaN                 NaN               NaN
# 65                             NaN                 NaN               NaN
# 90                             NaN                 NaN               NaN
# 139                            3.0                 NaN               NaN
# 159                            NaN                 NaN               1.0
# 165                            NaN                 NaN               NaN
# 197                            NaN                 NaN               NaN
# 219                            NaN                 NaN               NaN
# 238                            NaN                 NaN               NaN
# 329                            NaN                 NaN               NaN
# 353                            NaN                 4.0               NaN
# 356                            NaN                 NaN               NaN
# 390                            NaN                 NaN               2.0
# 424                            NaN                 NaN               NaN
# 433                            NaN                 NaN               NaN
# 569                            NaN                 NaN               NaN
# 579                            NaN                 NaN               NaN
#
#      Virgin Suicides, The (1999)  ¡Three Amigos! (1986)  \
# 27                           3.0                    NaN
# 44                           NaN                    NaN
# 65                           NaN                    NaN
# 90                           NaN                    NaN
# 139                          NaN                    NaN
# 159                          NaN                    NaN
# 165                          NaN                    NaN
# 197                          NaN                    2.0
# 219                          NaN                    NaN
# 238                          NaN                    3.0
# 329                          NaN                    NaN
# 353                          NaN                    NaN
# 356                          4.0                    NaN
# 390                          NaN                    NaN
# 424                          NaN                    NaN
# 433                          NaN                    NaN
# 569                          NaN                    NaN
# 579                          5.0                    NaN
#
#      Waking Ned Devine (a.k.a. Waking Ned) (1998)  Jacob's Ladder (1990)
# 27                                            NaN                    NaN
# 44                                            NaN                    NaN
# 65                                            NaN                    NaN
# 90                                            NaN                    NaN
# 139                                           NaN                    NaN
# 159                                           NaN                    NaN
# 165                                           NaN                    NaN
# 197                                           NaN                    NaN
# 219                                           3.5                    NaN
# 238                                           NaN                    NaN
# 329                                           NaN                    NaN
# 353                                           NaN                    NaN
# 356                                           NaN                    NaN
# 390                                           NaN                    NaN
# 424                                           NaN                    NaN
# 433                                           NaN                    NaN
# 569                                           NaN                    NaN
# 579                                           NaN                    NaN
#
# [18 rows x 1000 columns]

# %%
# Fill in the name of the column/movie. e.g. 'Forrest Gump (1994)'
movie_name = "Matrix, The (1999)"
cluster[movie_name].mean()
# Out:
# 4.5

# %%
# The average rating of 20 movies as rated by the users in the cluster
cluster.mean().head(20)
# Out:
# Forrest Gump (1994)                                      4.361111
# Star Wars: Episode V - The Empire Strikes Back (1980)    4.361111
# Ghostbusters (a.k.a. Ghost Busters) (1984)               3.722222
# Star Wars: Episode I - The Phantom Menace (1999)         3.055556
# Star Wars: Episode IV - A New Hope (1977)                4.277778
# Saving Private Ryan (1998)                               4.305556
# Star Wars: Episode VI - Return of the Jedi (1983)        4.250000
# Terminator, The (1984)                                   3.617647
# Men in Black (a.k.a. MIB) (1997)                         3.500000
# Gladiator (2000)                                         3.823529
# Independence Day (a.k.a. ID4) (1996)                     3.029412
# Spider-Man (2002)                                        3.647059
# Fight Club (1999)                                        4.352941
# Pulp Fiction (1994)                                      4.676471
# Matrix, The (1999)                                       4.500000
# Minority Report (2002)                                   3.875000
# Terminator 2: Judgment Day (1991)                        4.093750
# Shrek (2001)                                             4.187500
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)                4.375000
# Sixth Sense, The (1999)                                  3.968750
# dtype: float64

# %%
cluster
# Out:
#     Forrest Gump (1994)  \
# 3                   3.0
# 17                  4.0
# 9                   5.0
# 14                  5.0
# 1                   5.0
# 10                  5.0
# 0                   4.0
# 15                  4.5
# 13                  5.0
# 4                   4.0
# 5                   3.0
# 11                  4.5
# 16                  4.0
# 12                  3.5
# 2                   5.0
# 6                   4.0
# 7                   5.0
# 8                   5.0
#
#     Star Wars: Episode V - The Empire Strikes Back (1980)  \
# 3                                                     4.5
# 17                                                    4.0
# 9                                                     5.0
# 14                                                    3.0
# 1                                                     5.0
# 10                                                    5.0
# 0                                                     4.0
# 15                                                    5.0
# 13                                                    5.0
# 4                                                     3.0
# 5                                                     4.0
# 11                                                    4.0
# 16                                                    4.0
# 12                                                    4.5
# 2                                                     4.0
# 6                                                     4.5
# 7                                                     5.0
# 8                                                     5.0
#
#     Ghostbusters (a.k.a. Ghost Busters) (1984)  \
# 3                                          4.5
# 17                                         4.0
# 9                                          4.0
# 14                                         2.5
# 1                                          4.0
# 10                                         4.0
# 0                                          1.5
# 15                                         5.0
# 13                                         4.0
# 4                                          4.0
# 5                                          4.0
# 11                                         4.0
# 16                                         3.5
# 12                                         4.0
# 2                                          3.5
# 6                                          3.5
# 7                                          2.0
# 8                                          5.0
#
#     Star Wars: Episode I - The Phantom Menace (1999)  \
# 3                                                4.0
# 17                                               4.0
# 9                                                3.5
# 14                                               3.0
# 1                                                4.0
# 10                                               3.0
# 0                                                4.0
# 15                                               0.5
# 13                                               1.0
# 4                                                4.0
# 5                                                2.0
# 11                                               3.5
# 16                                               3.5
# 12                                               3.0
# 2                                                3.0
# 6                                                3.5
# 7                                                2.0
# 8                                                3.5
#
#     Star Wars: Episode IV - A New Hope (1977)  Saving Private Ryan (1998)  \
# 3                                         4.5                         4.5
# 17                                        4.0                         5.0
# 9                                         5.0                         5.0
# 14                                        3.0                         4.0
# 1                                         5.0                         5.0
# 10                                        4.0                         3.5
# 0                                         4.0                         3.5
# 15                                        5.0                         5.0
# 13                                        5.0                         2.0
# 4                                         4.0                         5.0
# 5                                         5.0                         5.0
# 11                                        4.0                         3.5
# 16                                        3.5                         4.0
# 12                                        4.0                         4.5
# 2                                         2.5                         4.5
# 6                                         4.5                         4.5
# 7                                         5.0                         4.0
# 8                                         5.0                         5.0
#
#     Star Wars: Episode VI - Return of the Jedi (1983)  Terminator, The (1984)  \
# 3                                                 4.0                     4.5
# 17                                                4.0                     3.5
# 9                                                 5.0                     4.0
# 14                                                3.0                     3.0
# 1                                                 5.0                     3.0
# 10                                                5.0                     2.5
# 0                                                 4.0                     4.5
# 15                                                4.5                     3.5
# 13                                                4.0                     4.0
# 4                                                 3.5                     3.0
# 5                                                 5.0                     4.0
# 11                                                4.0                     4.0
# 16                                                4.0                     3.5
# 12                                                4.0                     NaN
# 2                                                 3.0                     4.0
# 6                                                 5.0                     3.0
# 7                                                 5.0                     3.0
# 8                                                 4.5                     4.5
#
#     Men in Black (a.k.a. MIB) (1997)  Gladiator (2000)  ...  Magnolia (1999)  \
# 3                                3.5               3.5  ...              NaN
# 17                               4.0               4.0  ...              NaN
# 9                                4.0               4.5  ...              NaN
# 14                               3.5               4.5  ...              NaN
# 1                                3.0               5.0  ...              NaN
# 10                               4.0               4.0  ...              NaN
# 0                                3.0               4.0  ...              NaN
# 15                               3.5               3.5  ...              2.0
# 13                               2.0               1.0  ...              5.0
# 4                                3.0               4.0  ...              NaN
# 5                                2.0               5.0  ...              4.5
# 11                               3.5               3.5  ...              NaN
# 16                               4.0               4.0  ...              NaN
# 12                               3.5               4.5  ...              NaN
# 2                                NaN               3.5  ...              NaN
# 6                                4.0               3.5  ...              4.0
# 7                                4.0               3.0  ...              3.0
# 8                                5.0               NaN  ...              NaN
#
#     Blade (1998)  Hotel Rwanda (2004)  \
# 3            NaN                  NaN
# 17           4.5                  3.0
# 9            4.0                  NaN
# 14           3.5                  4.5
# 1            NaN                  NaN
# 10           NaN                  NaN
# 0            NaN                  4.0
# 15           NaN                  NaN
# 13           NaN                  NaN
# 4            NaN                  3.0
# 5            NaN                  NaN
# 11           3.5                  NaN
# 16           NaN                  NaN
# 12           NaN                  NaN
# 2            NaN                  NaN
# 6            4.0                  4.0
# 7            NaN                  NaN
# 8            NaN                  NaN
#
#     Monty Python's The Meaning of Life (1983)  Cool Hand Luke (1967)  \
# 3                                         4.0                    3.0
# 17                                        3.0                    NaN
# 9                                         4.0                    NaN
# 14                                        NaN                    NaN
# 1                                         NaN                    NaN
# 10                                        NaN                    NaN
# 0                                         2.5                    3.5
# 15                                        NaN                    NaN
# 13                                        NaN                    NaN
# 4                                         NaN                    4.0
# 5                                         NaN                    NaN
# 11                                        NaN                    NaN
# 16                                        NaN                    NaN
# 12                                        NaN                    5.0
# 2                                         3.5                    NaN
# 6                                         NaN                    4.5
# 7                                         NaN                    NaN
# 8                                         NaN                    NaN
#
#     Boot, Das (Boat, The) (1981)  The Butterfly Effect (2004)  \
# 3                            NaN                          NaN
# 17                           NaN                          3.5
# 9                            NaN                          3.5
# 14                           NaN                          NaN
# 1                            NaN                          NaN
# 10                           NaN                          NaN
# 0                            3.5                          NaN
# 15                           NaN                          NaN
# 13                           5.0                          NaN
# 4                            3.0                          NaN
# 5                            NaN                          NaN
# 11                           4.0                          3.5
# 16                           3.5                          4.0
# 12                           NaN                          4.0
# 2                            NaN                          NaN
# 6                            NaN                          NaN
# 7                            NaN                          NaN
# 8                            NaN                          NaN
#
#     Enemy at the Gates (2001)  Clueless (1995)  Dune (1984)
# 3                         NaN              1.5          NaN
# 17                        NaN              NaN          4.5
# 9                         5.0              NaN          NaN
# 14                        NaN              NaN          NaN
# 1                         NaN              3.0          3.0
# 10                        NaN              NaN          NaN
# 0                         4.0              NaN          5.0
# 15                        1.5              3.0          NaN
# 13                        NaN              NaN          4.0
# 4                         5.0              NaN          NaN
# 5                         3.0              NaN          1.0
# 11                        NaN              NaN          NaN
# 16                        NaN              3.0          NaN
# 12                        NaN              4.5          NaN
# 2                         NaN              NaN          NaN
# 6                         NaN              NaN          NaN
# 7                         NaN              NaN          NaN
# 8                         NaN              NaN          NaN
#
# [18 rows x 300 columns]

# %%
# Predict for a specific user

# Pick a user ID from the dataset
user_id = 7
# Get all this user's ratings
user_2_ratings  = cluster.loc[user_id, :]
# Which movies did they not rate?
user_2_unrated_movies =  user_2_ratings[user_2_ratings.isnull()]
# What are the ratings of these movies the user did not rate?
avg_ratings = pd.concat([user_2_unrated_movies, cluster.mean()], axis=1, join='inner').loc[:,0]
# Let's sort by rating so the highest rated movies are presented first
avg_ratings.sort_values(ascending=False)[:20]
# Out:
# Monty Python and the Holy Grail (1975)                                       4.636364
# Dark Knight, The (2008)                                                      4.583333
# Dark City (1998)                                                             4.583333
# Godfather, The (1972)                                                        4.562500
# Finding Nemo (2003)                                                          4.454545
# Nightmare Before Christmas, The (1993)                                       4.416667
# Office Space (1999)                                                          4.416667
# Lord of the Rings: The Return of the King, The (2003)                        4.392857
# Schindler's List (1993)                                                      4.363636
# Platoon (1986)                                                               4.357143
# Donnie Darko (2001)                                                          4.350000
# 28 Days Later (2002)                                                         4.333333
# Full Metal Jacket (1987)                                                     4.318182
# Kill Bill: Vol. 2 (2004)                                                     4.318182
# Batman Begins (2005)                                                         4.277778
# Incredibles, The (2004)                                                      4.269231
# Children of Men (2006)                                                       4.214286
# Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)    4.214286
# Léon: The Professional (a.k.a. The Professional) (Léon) (1994)               4.208333
# Shrek (2001)                                                                 4.187500
# Name: 0, dtype: float64

# %% [markdown]
# ## Using Collaborative Filtering (With fast.ai)

# %%
! [ -e /content ] && pip install -Uqq fastai

# %%
from fastai.tabular.all import *
from fastai.collab import *

# %% [markdown]
# ### Training a model

# %% [markdown]
# For this, we will use the [Movielens 100k data dataset](https://grouplens.org/datasets/movielens/100k/). We can download it easily and decompress it with the following function:

# %%
path = untar_data(URLs.ML_100k)

# %% [markdown]
# The main table is in `u.data`. Since it's not a proper csv, we have to specify a few things while opening it: the tab delimiter, the columns we want to keep and their names.

# %%
ratings = pd.read_csv(path/'u.data', delimiter='\t', header=None,
                      usecols=(0,1,2), names=['user','movie','rating'])
ratings.head()
# Out:
#    user  movie  rating
# 0   196    242       3
# 1   186    302       3
# 2    22    377       1
# 3   244     51       2
# 4   166    346       1

# %% [markdown]
# Movie ids are not ideal to look at things, so we load the corresponding movie id to the title that is in the table `u.item`:

# %%
movies = pd.read_csv(path/'u.item',  delimiter='|', encoding='latin-1',
                     usecols=(0,1), names=('movie','title'), header=None)
movies.head()
# Out:
#    movie              title
# 0      1   Toy Story (1995)
# 1      2   GoldenEye (1995)
# 2      3  Four Rooms (1995)
# 3      4  Get Shorty (1995)
# 4      5     Copycat (1995)

# %% [markdown]
# Next we merge it to our ratings table:

# %%
ratings = ratings.merge(movies)
ratings.head()
# Out:
#    user  movie  rating         title
# 0   196    242       3  Kolya (1996)
# 1    63    242       3  Kolya (1996)
# 2   226    242       5  Kolya (1996)
# 3   154    242       3  Kolya (1996)
# 4   306    242       5  Kolya (1996)

# %% [markdown]
# We can then build a `DataLoaders` object from this table. By default, it takes the first column for user, the second column for the item (here our movies) and the third column for the ratings. We need to change the value of `item_name` in our case, to use the titles instead of the ids:

# %%
dls = CollabDataLoaders.from_df(ratings, item_name='title', bs=64)

# %% [markdown]
# In all applications, when the data has been assembled in a `DataLoaders`, you can have a look at it with the `show_batch` method:

# %%
dls.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user</th>
#       <th>title</th>
#       <th>rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>707</td>
#       <td>Quiet Man, The (1952)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>486</td>
#       <td>Boy's Life 2 (1997)</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>940</td>
#       <td>Sleepers (1996)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>286</td>
#       <td>Much Ado About Nothing (1993)</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>235</td>
#       <td>Singin' in the Rain (1952)</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>445</td>
#       <td>Terminator, The (1984)</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>70</td>
#       <td>Alien: Resurrection (1997)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>421</td>
#       <td>Sting, The (1973)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>495</td>
#       <td>True Lies (1994)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>308</td>
#       <td>12 Angry Men (1957)</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# fastai can create and train a collaborative filtering model by using `collab_learner`:

# %%
learn = collab_learner(dls, n_factors=50, y_range=(0, 5.5))

# %% [markdown]
# It uses a simple dot product model with 50 latent factors. To train it using the 1cycle policy, we just run this command:

# %%
learn.fit_one_cycle(5, 5e-3, wd=0.1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.923398</td>
#       <td>0.935820</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.867808</td>
#       <td>0.868500</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.750456</td>
#       <td>0.827616</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.604268</td>
#       <td>0.818848</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.474857</td>
#       <td>0.820047</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Here's [some benchmarks](https://www.librec.net/release/v1.3/example.html) on the same dataset for the popular Librec system for collaborative filtering. They show best results based on RMSE of 0.91 (scroll down to the 100k dataset), which corresponds to an MSE of `0.91**2 = 0.83`. So in less than a minute, we got pretty good results!

# %% [markdown]
# ### Interpretation

# %% [markdown]
# Let's analyze the results of our previous model. We will keep the 1000 most rated movies for this:

# %%
g = ratings.groupby('title')['rating'].count()
top_movies = g.sort_values(ascending=False).index.values[:1000]
top_movies[:10]
# Out:
# array(['Star Wars (1977)', 'Contact (1997)', 'Fargo (1996)',
#        'Return of the Jedi (1983)', 'Liar Liar (1997)',
#        'English Patient, The (1996)', 'Scream (1996)', 'Toy Story (1995)',
#        'Air Force One (1997)', 'Independence Day (ID4) (1996)'],
#       dtype=object)

# %% [markdown]
# ### Movie bias

# %% [markdown]
# Our model has learned one bias per movie, a unique number independent of users that can be interpreted as the intrinsic "value" of the movie. We can grab the bias of each movie in our `top_movies` list with the following command:

# %%
movie_bias = learn.model.bias(top_movies, is_item=True)
movie_bias.shape
# Out:
# torch.Size([1000])

# %% [markdown]
# Let's compare those biases with the average ratings:

# %%
mean_ratings = ratings.groupby('title')['rating'].mean()
movie_ratings = [(b, i, mean_ratings.loc[i]) for i,b in zip(top_movies,movie_bias)]

# %% [markdown]
# Now let's have a look at the movies with the worst bias:

# %%
item0 = lambda o:o[0]
sorted(movie_ratings, key=item0)[:15]
# Out:
# [(tensor(-0.3686),
#   'Children of the Corn: The Gathering (1996)',
#   1.3157894736842106),
#  (tensor(-0.2953), 'Free Willy 3: The Rescue (1997)', 1.7407407407407407),
#  (tensor(-0.2913), 'Home Alone 3 (1997)', 1.894736842105263),
#  (tensor(-0.2772),
#   'Lawnmower Man 2: Beyond Cyberspace (1996)',
#   1.7142857142857142),
#  (tensor(-0.2593), 'Kansas City (1996)', 2.260869565217391),
#  (tensor(-0.2578), 'Mortal Kombat: Annihilation (1997)', 1.9534883720930232),
#  (tensor(-0.2516), 'Flintstones, The (1994)', 2.064516129032258),
#  (tensor(-0.2463), 'Cable Guy, The (1996)', 2.339622641509434),
#  (tensor(-0.2424), 'Beautician and the Beast, The (1997)', 2.313953488372093),
#  (tensor(-0.2307), 'Island of Dr. Moreau, The (1996)', 2.1578947368421053),
#  (tensor(-0.2290), 'Striptease (1996)', 2.2388059701492535),
#  (tensor(-0.2176), 'Coneheads (1993)', 2.2195121951219514),
#  (tensor(-0.2170), 'Barb Wire (1996)', 1.9333333333333333),
#  (tensor(-0.2117), 'Leave It to Beaver (1997)', 1.8409090909090908),
#  (tensor(-0.2063), 'Hellraiser: Bloodline (1996)', 2.0)]

# %% [markdown]
# Or the ones with the best bias:

# %%
sorted(movie_ratings, key=lambda o: o[0], reverse=True)[:15]
# Out:
# [(tensor(0.5967), "Schindler's List (1993)", 4.466442953020135),
#  (tensor(0.5751), 'Shawshank Redemption, The (1994)', 4.445229681978798),
#  (tensor(0.5546), 'Silence of the Lambs, The (1991)', 4.28974358974359),
#  (tensor(0.5504), 'L.A. Confidential (1997)', 4.161616161616162),
#  (tensor(0.5461), 'Rear Window (1954)', 4.3875598086124405),
#  (tensor(0.5312), 'Titanic (1997)', 4.2457142857142856),
#  (tensor(0.5285), 'As Good As It Gets (1997)', 4.196428571428571),
#  (tensor(0.5141), 'Star Wars (1977)', 4.3584905660377355),
#  (tensor(0.5029), 'Good Will Hunting (1997)', 4.262626262626263),
#  (tensor(0.5015), 'Usual Suspects, The (1995)', 4.385767790262173),
#  (tensor(0.4718), 'Close Shave, A (1995)', 4.491071428571429),
#  (tensor(0.4713), 'Casablanca (1942)', 4.45679012345679),
#  (tensor(0.4576), 'Raiders of the Lost Ark (1981)', 4.252380952380952),
#  (tensor(0.4563), 'Godfather, The (1972)', 4.283292978208232),
#  (tensor(0.4389), 'Wrong Trousers, The (1993)', 4.466101694915254)]

# %% [markdown]
# There is certainly a strong correlation!

# %% [markdown]
# ### Movie weights

# %% [markdown]
# Now let's try to analyze the latent factors our model has learned. We can grab the weights for each movie in `top_movies` the same way as we did for the bias before.

# %%
movie_w = learn.model.weight(top_movies, is_item=True)
movie_w.shape
# Out:
# torch.Size([1000, 50])

# %% [markdown]
# Let's try a PCA to reduce the dimensions and see if we can see what the model learned:

# %%
movie_pca = movie_w.pca(3)
movie_pca.shape
# Out:
# torch.Size([1000, 3])

# %%
fac0,fac1,fac2 = movie_pca.t()
movie_comp = [(f, i) for f,i in zip(fac0, top_movies)]

# %% [markdown]
# Here are the highest score on the first dimension:

# %%
sorted(movie_comp, key=itemgetter(0), reverse=True)[:10]
# Out:
# [(tensor(1.0971), 'Lawrence of Arabia (1962)'),
#  (tensor(1.0826), 'Casablanca (1942)'),
#  (tensor(1.0773), 'Close Shave, A (1995)'),
#  (tensor(1.0370), 'Some Folks Call It a Sling Blade (1993)'),
#  (tensor(1.0291), 'Chinatown (1974)'),
#  (tensor(1.0251), 'Top Hat (1935)'),
#  (tensor(1.0056), 'Manchurian Candidate, The (1962)'),
#  (tensor(0.9946), "One Flew Over the Cuckoo's Nest (1975)"),
#  (tensor(0.9926), '12 Angry Men (1957)'),
#  (tensor(0.9923),
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)')]

# %% [markdown]
# And the worst:

# %%
sorted(movie_comp, key=itemgetter(0))[:10]
# Out:
# [(tensor(-1.2350), 'Home Alone 3 (1997)'),
#  (tensor(-1.2169), "McHale's Navy (1997)"),
#  (tensor(-1.2133), 'Jungle2Jungle (1997)'),
#  (tensor(-1.1773), 'Bio-Dome (1996)'),
#  (tensor(-1.1649), 'Free Willy 3: The Rescue (1997)'),
#  (tensor(-1.1347), 'Flipper (1996)'),
#  (tensor(-1.1031), 'Children of the Corn: The Gathering (1996)'),
#  (tensor(-1.0855), 'Leave It to Beaver (1997)'),
#  (tensor(-1.0745), 'Grease 2 (1982)'),
#  (tensor(-1.0634), 'Congo (1995)')]

# %% [markdown]
# Same thing for our second dimension:

# %%
movie_comp = [(f, i) for f,i in zip(fac1, top_movies)]

# %%
sorted(movie_comp, key=itemgetter(0), reverse=True)[:10]
# Out:
# [(tensor(0.9310), 'Three Colors: Blue (1993)'),
#  (tensor(0.9309), 'Stupids, The (1996)'),
#  (tensor(0.8797), 'Serial Mom (1994)'),
#  (tensor(0.8734), 'Nosferatu (Nosferatu, eine Symphonie des Grauens) (1922)'),
#  (tensor(0.8451), 'Trainspotting (1996)'),
#  (tensor(0.8364), 'Cable Guy, The (1996)'),
#  (tensor(0.7860), 'Keys to Tulsa (1997)'),
#  (tensor(0.7823), 'Jude (1996)'),
#  (tensor(0.7735), 'Brazil (1985)'),
#  (tensor(0.7604), 'Marked for Death (1990)')]

# %%
sorted(movie_comp, key=itemgetter(0))[:10]
# Out:
# [(tensor(-1.1308), 'Braveheart (1995)'),
#  (tensor(-1.0838), 'Raiders of the Lost Ark (1981)'),
#  (tensor(-1.0020), 'Titanic (1997)'),
#  (tensor(-0.9348), 'Independence Day (ID4) (1996)'),
#  (tensor(-0.9025), 'American President, The (1995)'),
#  (tensor(-0.8860), 'Indiana Jones and the Last Crusade (1989)'),
#  (tensor(-0.7988), 'Fugitive, The (1993)'),
#  (tensor(-0.7925), "Mr. Holland's Opus (1995)"),
#  (tensor(-0.7796), 'E.T. the Extra-Terrestrial (1982)'),
#  (tensor(-0.7703), 'Speed (1994)')]

# %% [markdown]
# And we can even plot the movies according to their scores on those dimensions:

# %%
idxs = np.random.choice(len(top_movies), 50, replace=False)
idxs = list(range(50))
X = fac0[idxs]
Y = fac2[idxs]
plt.figure(figsize=(15,15))
plt.scatter(X, Y)
for i, x, y in zip(top_movies[idxs], X, Y):
    plt.text(x,y,i, color=np.random.rand(3)*0.7, fontsize=11)
plt.show()

# %% [markdown]
# # Exercise 2
#
# ## Play around with different collaborative filtering model parameters such as n_factors and other parameters.
# ## Identify if any such parameters have impact on the speed of convergence or the performance on the model

# %%
# !pip install scikit-surprise
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise.prediction_algorithms import SVD

# Load the dataset (you can replace 'ml-100k' with any other dataset supported by Surprise)
data = Dataset.load_builtin('ml-100k')

# Define a parameter grid to experiment with
param_grid = {'n_factors': [50, 100, 150],
              'reg_all': [0.01, 0.02, 0.03],
              'lr_all': [0.005, 0.01, 0.015],
              'n_epochs': [10, 20, 30]}

# Iterate over parameter combinations
for n_factors in param_grid['n_factors']:
    for reg_all in param_grid['reg_all']:
        for lr_all in param_grid['lr_all']:
            for n_epochs in param_grid['n_epochs']:
                # Define the model with current parameters
                model = SVD(n_factors=n_factors, reg_all=reg_all, lr_all=lr_all, n_epochs=n_epochs)

                # Perform cross-validation
                cv_results = cross_validate(model, data, measures=['RMSE'], cv=5, verbose=True)

                # Extract and print the mean RMSE
                mean_rmse = cv_results['test_rmse'].mean()
                print(f"Parameters: n_factors={n_factors}, reg_all={reg_all}, lr_all={lr_all}, n_epochs={n_epochs}")
                print(f"Mean RMSE: {mean_rmse}")
# Out:
# Requirement already satisfied: scikit-surprise in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.4)
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9414  0.9446  0.9496  0.9493  0.9472  0.9464  0.0031
# Fit time          0.77    1.06    1.04    0.75    1.18    0.96    0.17
# Test time         0.19    0.19    0.70    0.23    0.52    0.36    0.21
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.9464264105260002
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9358  0.9338  0.9336  0.9426  0.9407  0.9373  0.0037
# Fit time          2.12    1.61    1.91    1.85    3.17    2.13    0.55
# Test time         0.20    0.27    0.50    0.24    0.28    0.30    0.11
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9373093288355587
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9526  0.9537  0.9480  0.9580  0.9554  0.9536  0.0033
# Fit time          2.57    1.03    1.08    1.04    1.06    1.36    0.61
# Test time         0.10    0.11    0.12    0.31    0.15    0.16    0.08
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9535518186510916
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9438  0.9401  0.9365  0.9435  0.9320  0.9392  0.0045
# Fit time          0.39    0.57    0.59    0.51    0.38    0.49    0.09
# Test time         0.11    0.17    0.18    0.31    0.11    0.18    0.07
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.9391755497628967
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9779  0.9674  0.9694  0.9669  0.9761  0.9716  0.0046
# Fit time          0.72    0.72    0.72    0.73    0.76    0.73    0.02
# Test time         0.11    0.10    0.11    0.33    0.11    0.15    0.09
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9715550136988714
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0219  1.0171  1.0143  1.0153  1.0195  1.0176  0.0028
# Fit time          1.02    1.11    1.30    1.56    1.48    1.29    0.21
# Test time         0.21    0.12    0.17    0.41    0.18    0.22    0.10
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.01, n_epochs=30
# Mean RMSE: 1.0176107977372026
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9414  0.9503  0.9535  0.9483  0.9546  0.9496  0.0047
# Fit time          0.66    0.42    0.40    0.42    0.39    0.46    0.10
# Test time         0.18    0.12    0.11    0.32    0.14    0.18    0.08
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.9496177938080173
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0186  1.0169  1.0189  1.0235  1.0114  1.0179  0.0039
# Fit time          0.74    0.72    0.70    1.08    1.02    0.85    0.16
# Test time         0.12    0.12    0.23    0.44    0.12    0.20    0.13
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.015, n_epochs=20
# Mean RMSE: 1.0178605909549656
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0295  1.0431  1.0577  1.0504  1.0549  1.0471  0.0101
# Fit time          1.03    1.03    1.07    0.99    1.03    1.03    0.02
# Test time         0.11    0.12    0.10    0.10    0.12    0.11    0.01
# Parameters: n_factors=50, reg_all=0.01, lr_all=0.015, n_epochs=30
# Mean RMSE: 1.0471264619244627
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9451  0.9382  0.9490  0.9481  0.9494  0.9459  0.0042
# Fit time          0.37    0.40    0.41    0.39    0.59    0.43    0.08
# Test time         0.11    0.11    0.10    0.15    0.18    0.13    0.03
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.945949230544217
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9360  0.9346  0.9279  0.9324  0.9363  0.9334  0.0031
# Fit time          1.03    0.74    0.74    0.73    0.74    0.80    0.12
# Test time         0.11    0.12    0.13    0.11    0.11    0.12    0.01
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9334234858637631
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9419  0.9399  0.9356  0.9418  0.9300  0.9378  0.0045
# Fit time          1.01    1.09    1.06    1.05    1.75    1.19    0.28
# Test time         0.10    0.11    0.11    0.19    0.11    0.13    0.03
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9378307406844282
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9371  0.9378  0.9220  0.9402  0.9333  0.9341  0.0064
# Fit time          0.39    0.40    0.42    0.41    0.39    0.40    0.01
# Test time         0.20    0.11    0.16    0.43    0.11    0.20    0.12
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.9341002418314182
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9515  0.9589  0.9593  0.9535  0.9531  0.9553  0.0032
# Fit time          0.72    0.75    0.71    0.72    0.70    0.72    0.02
# Test time         0.11    0.11    0.13    0.12    0.11    0.12    0.01
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9552746571363008
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9813  0.9782  0.9807  0.9860  0.9824  0.9817  0.0026
# Fit time          1.31    3.09    1.35    1.00    1.08    1.56    0.77
# Test time         0.19    0.18    0.33    0.11    0.11    0.18    0.08
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.01, n_epochs=30
# Mean RMSE: 0.9817213339825068
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9369  0.9374  0.9394  0.9398  0.9382  0.9384  0.0011
# Fit time          0.36    0.44    0.38    0.38    0.40    0.39    0.03
# Test time         0.10    0.12    0.34    0.19    0.18    0.19    0.08
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.9383553862657461
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9874  0.9832  0.9823  0.9816  0.9882  0.9845  0.0028
# Fit time          1.13    0.81    0.76    0.72    0.77    0.84    0.15
# Test time         0.18    0.11    0.34    0.20    0.19    0.20    0.08
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.015, n_epochs=20
# Mean RMSE: 0.9845370271391476
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9981  1.0139  1.0058  1.0152  1.0091  1.0084  0.0062
# Fit time          1.06    1.03    1.03    1.05    1.63    1.16    0.23
# Test time         0.12    0.11    0.21    0.32    0.18    0.19    0.08
# Parameters: n_factors=50, reg_all=0.02, lr_all=0.015, n_epochs=30
# Mean RMSE: 1.0084054557715445
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9542  0.9410  0.9466  0.9423  0.9466  0.9461  0.0046
# Fit time          0.45    0.40    0.37    0.37    0.39    0.40    0.03
# Test time         0.11    0.17    0.12    0.50    0.20    0.22    0.14
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.9461445679843857
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9354  0.9327  0.9314  0.9287  0.9389  0.9334  0.0035
# Fit time          0.67    0.71    0.70    0.70    0.70    0.70    0.01
# Test time         0.12    0.11    0.18    0.33    0.11    0.17    0.09
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9334193240927007
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9293  0.9370  0.9286  0.9270  0.9289  0.9301  0.0035
# Fit time          1.33    1.45    1.05    1.03    1.02    1.17    0.18
# Test time         0.20    0.11    0.12    0.32    0.11    0.17    0.08
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9301425818291719
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9272  0.9321  0.9321  0.9353  0.9345  0.9322  0.0029
# Fit time          0.39    0.37    0.38    0.39    0.42    0.39    0.02
# Test time         0.10    0.14    0.12    0.32    0.12    0.16    0.08
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.9322379539815892
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9462  0.9344  0.9368  0.9391  0.9323  0.9378  0.0048
# Fit time          0.70    0.70    1.19    0.74    0.69    0.80    0.19
# Test time         0.11    0.19    0.18    0.35    0.10    0.19    0.09
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9377745269994682
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9631  0.9592  0.9539  0.9600  0.9564  0.9585  0.0032
# Fit time          1.01    1.05    1.04    1.01    1.05    1.03    0.02
# Test time         0.12    0.19    0.11    0.12    0.40    0.19    0.11
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.01, n_epochs=30
# Mean RMSE: 0.9585187321524149
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9263  0.9277  0.9325  0.9282  0.9320  0.9293  0.0024
# Fit time          0.38    0.41    0.81    0.59    0.38    0.51    0.17
# Test time         0.11    0.19    0.19    0.11    0.32    0.18    0.08
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.9293391589283283
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9569  0.9658  0.9504  0.9517  0.9596  0.9569  0.0056
# Fit time          0.72    0.72    0.69    0.71    0.72    0.71    0.01
# Test time         0.13    0.11    0.11    0.11    0.11    0.11    0.01
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.015, n_epochs=20
# Mean RMSE: 0.9568961653204677
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9791  0.9779  0.9733  0.9843  0.9746  0.9778  0.0038
# Fit time          0.99    1.01    1.07    1.71    1.03    1.16    0.27
# Test time         0.40    0.11    0.17    0.17    0.12    0.19    0.11
# Parameters: n_factors=50, reg_all=0.03, lr_all=0.015, n_epochs=30
# Mean RMSE: 0.9778359785769638
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9448  0.9447  0.9580  0.9479  0.9444  0.9480  0.0052
# Fit time          0.58    0.56    0.53    0.58    0.56    0.56    0.02
# Test time         0.44    0.16    0.11    0.15    0.11    0.20    0.12
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.9479806254358516
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9456  0.9441  0.9424  0.9412  0.9426  0.9432  0.0015
# Fit time          1.07    1.11    1.20    1.88    1.17    1.29    0.30
# Test time         0.34    0.11    0.18    0.13    0.12    0.18    0.09
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9431872429353071
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9571  0.9509  0.9591  0.9602  0.9561  0.9567  0.0032
# Fit time          1.68    1.55    1.58    1.56    2.25    1.72    0.27
# Test time         0.33    0.11    0.11    0.11    0.17    0.17    0.09
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9566741055248984
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9499  0.9346  0.9419  0.9461  0.9411  0.9427  0.0051
# Fit time          0.58    0.57    0.58    0.56    0.56    0.57    0.01
# Test time         0.11    0.12    0.11    0.16    0.11    0.12    0.02
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.9426846950075778
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9788  0.9867  0.9735  0.9735  0.9754  0.9776  0.0050
# Fit time          1.08    1.11    1.10    1.04    1.68    1.20    0.24
# Test time         0.10    0.12    0.12    0.11    0.18    0.13    0.03
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9775827785616673
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9966  1.0083  0.9913  1.0035  1.0044  1.0008  0.0061
# Fit time          1.54    1.56    1.55    1.60    1.53    1.55    0.02
# Test time         0.31    0.11    0.10    0.15    0.11    0.16    0.08
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.01, n_epochs=30
# Mean RMSE: 1.0007911212780458
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9621  0.9628  0.9503  0.9557  0.9644  0.9590  0.0053
# Fit time          0.55    0.87    0.74    0.56    0.58    0.66    0.13
# Test time         0.40    0.18    0.12    0.11    0.10    0.18    0.11
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.9590373546753697
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0034  1.0007  0.9946  0.9896  1.0107  0.9998  0.0073
# Fit time          1.07    1.08    1.13    1.09    1.08    1.09    0.02
# Test time         0.11    0.40    0.11    0.14    0.11    0.17    0.11
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.015, n_epochs=20
# Mean RMSE: 0.9998080798786603
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0194  1.0200  1.0204  1.0117  1.0079  1.0159  0.0051
# Fit time          2.17    1.76    1.55    1.63    1.51    1.72    0.24
# Test time         0.19    0.38    0.14    0.11    0.11    0.18    0.10
# Parameters: n_factors=100, reg_all=0.01, lr_all=0.015, n_epochs=30
# Mean RMSE: 1.0158857616868509
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9470  0.9495  0.9462  0.9540  0.9457  0.9485  0.0031
# Fit time          0.55    0.57    0.58    0.88    0.81    0.68    0.14
# Test time         0.11    0.11    0.11    0.18    0.11    0.12    0.03
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.9485005110489416
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9375  0.9334  0.9371  0.9338  0.9330  0.9349  0.0019
# Fit time          1.05    1.05    1.10    1.12    1.05    1.08    0.03
# Test time         0.33    0.11    0.11    0.12    0.12    0.16    0.09
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9349433790743571
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9415  0.9376  0.9409  0.9426  0.9409  0.9407  0.0017
# Fit time          1.56    2.21    1.67    1.57    1.61    1.72    0.24
# Test time         0.33    0.19    0.12    0.19    0.10    0.19    0.08
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9406914077518016
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9398  0.9311  0.9334  0.9406  0.9381  0.9366  0.0037
# Fit time          0.55    0.57    0.56    0.74    0.98    0.68    0.16
# Test time         0.11    0.40    0.11    0.17    0.22    0.20    0.11
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.93659866042208
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9670  0.9597  0.9545  0.9520  0.9447  0.9556  0.0075
# Fit time          1.81    1.06    1.10    1.11    1.10    1.23    0.29
# Test time         0.16    0.38    0.13    0.12    0.11    0.18    0.10
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9556074139823856
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9598  0.9723  0.9703  0.9754  0.9751  0.9706  0.0057
# Fit time          1.57    1.55    2.45    1.62    1.56    1.75    0.35
# Test time         0.13    0.37    0.13    0.10    0.11    0.17    0.10
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.01, n_epochs=30
# Mean RMSE: 0.9705694183375689
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9502  0.9462  0.9420  0.9329  0.9356  0.9414  0.0064
# Fit time          0.54    0.54    0.54    0.55    0.64    0.56    0.04
# Test time         0.12    0.32    0.11    0.11    0.10    0.15    0.09
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.9413707864074368
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9657  0.9719  0.9767  0.9712  0.9681  0.9707  0.0037
# Fit time          1.06    1.54    1.28    1.06    1.13    1.22    0.18
# Test time         0.11    0.46    0.11    0.11    0.11    0.18    0.14
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.015, n_epochs=20
# Mean RMSE: 0.9707043225860847
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9830  0.9819  0.9660  0.9737  0.9783  0.9766  0.0062
# Fit time          1.55    1.57    1.61    2.34    1.56    1.73    0.31
# Test time         0.11    0.32    0.11    0.18    0.11    0.17    0.08
# Parameters: n_factors=100, reg_all=0.02, lr_all=0.015, n_epochs=30
# Mean RMSE: 0.9765768602813022
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9506  0.9407  0.9450  0.9457  0.9549  0.9474  0.0049
# Fit time          0.55    0.56    0.56    0.55    0.60    0.56    0.02
# Test time         0.13    0.16    0.19    0.11    0.11    0.14    0.03
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.9473862041448017
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9283  0.9375  0.9280  0.9360  0.9351  0.9330  0.0040
# Fit time          1.03    1.04    1.19    1.58    1.15    1.20    0.20
# Test time         0.11    0.11    0.44    0.18    0.11    0.19    0.13
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.93298009125603
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9364  0.9299  0.9258  0.9290  0.9367  0.9315  0.0043
# Fit time          1.52    1.54    1.59    1.50    2.34    1.70    0.32
# Test time         0.13    0.21    0.32    0.16    0.18    0.20    0.06
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9315499521737175
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9331  0.9313  0.9328  0.9308  0.9359  0.9328  0.0018
# Fit time          0.56    0.54    0.59    0.57    0.56    0.56    0.02
# Test time         0.11    0.11    0.34    0.11    0.12    0.16    0.09
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.9327853903170531
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9372  0.9484  0.9285  0.9370  0.9450  0.9392  0.0069
# Fit time          1.07    1.06    1.06    1.03    1.73    1.19    0.27
# Test time         0.11    0.13    0.11    0.39    0.18    0.18    0.11
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9392426527485235
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9498  0.9478  0.9508  0.9587  0.9379  0.9490  0.0067
# Fit time          1.51    1.53    1.56    1.54    1.55    1.54    0.02
# Test time         0.11    0.12    0.11    0.33    0.11    0.16    0.09
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.01, n_epochs=30
# Mean RMSE: 0.9489991489762671
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9273  0.9388  0.9233  0.9351  0.9357  0.9320  0.0058
# Fit time          0.56    0.87    0.82    0.55    0.60    0.68    0.14
# Test time         0.12    0.18    0.12    0.35    0.12    0.18    0.09
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.9320453693117285
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9392  0.9562  0.9492  0.9475  0.9502  0.9485  0.0055
# Fit time          1.02    1.06    1.06    1.05    1.05    1.05    0.01
# Test time         0.11    0.12    0.11    0.39    0.11    0.17    0.11
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.015, n_epochs=20
# Mean RMSE: 0.9484610119339967
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9528  0.9616  0.9655  0.9541  0.9530  0.9574  0.0052
# Fit time          1.99    1.76    1.52    1.65    1.56    1.70    0.17
# Test time         0.18    0.12    0.12    0.34    0.12    0.18    0.09
# Parameters: n_factors=100, reg_all=0.03, lr_all=0.015, n_epochs=30
# Mean RMSE: 0.9573726384172513
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9461  0.9607  0.9536  0.9442  0.9518  0.9513  0.0058
# Fit time          0.80    0.73    0.74    1.09    0.77    0.83    0.14
# Test time         0.12    0.14    0.18    0.46    0.13    0.21    0.13
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.9512786281333208
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9502  0.9427  0.9569  0.9439  0.9457  0.9479  0.0052
# Fit time          1.42    1.41    1.40    1.56    1.57    1.47    0.08
# Test time         0.14    0.12    0.12    0.34    0.14    0.17    0.08
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9478825510524604
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9614  0.9667  0.9579  0.9625  0.9643  0.9626  0.0029
# Fit time          2.87    2.19    2.61    2.42    3.31    2.68    0.39
# Test time         0.13    0.12    0.14    0.13    0.38    0.18    0.10
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9625550116364188
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9441  0.9468  0.9424  0.9499  0.9398  0.9446  0.0035
# Fit time          0.73    0.74    0.78    0.78    0.76    0.76    0.02
# Test time         0.12    0.14    0.12    0.12    0.34    0.17    0.08
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.94460940753087
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9742  0.9714  0.9744  0.9788  0.9753  0.9748  0.0024
# Fit time          1.45    1.55    1.99    2.01    1.65    1.73    0.23
# Test time         0.14    0.12    0.20    0.12    0.40    0.20    0.11
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9748479977683047
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9889  0.9753  0.9935  0.9922  0.9876  0.9875  0.0065
# Fit time          2.34    2.24    3.01    2.24    2.28    2.42    0.29
# Test time         0.12    0.12    0.19    0.16    0.35    0.19    0.08
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.01, n_epochs=30
# Mean RMSE: 0.9874979773611049
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9588  0.9562  0.9620  0.9594  0.9697  0.9613  0.0046
# Fit time          0.71    0.74    0.75    0.71    0.88    0.76    0.06
# Test time         0.14    0.14    0.12    0.14    0.43    0.19    0.12
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.961250320157783
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9861  0.9943  0.9894  0.9887  0.9886  0.9894  0.0027
# Fit time          1.89    1.57    1.55    1.41    1.37    1.56    0.18
# Test time         0.11    0.16    0.13    0.12    0.38    0.18    0.10
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.015, n_epochs=20
# Mean RMSE: 0.9893867435472192
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9854  0.9885  0.9944  0.9908  0.9886  0.9896  0.0030
# Fit time          2.46    2.50    2.24    2.25    2.36    2.36    0.11
# Test time         0.20    0.12    0.13    0.18    0.35    0.20    0.08
# Parameters: n_factors=150, reg_all=0.01, lr_all=0.015, n_epochs=30
# Mean RMSE: 0.9895594130523984
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9526  0.9512  0.9559  0.9461  0.9449  0.9502  0.0041
# Fit time          0.87    1.13    0.80    0.79    0.76    0.87    0.14
# Test time         0.18    0.18    0.12    0.12    0.39    0.20    0.10
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.9501528552105205
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9392  0.9460  0.9413  0.9435  0.9356  0.9411  0.0036
# Fit time          1.55    1.59    1.49    1.80    2.07    1.70    0.21
# Test time         0.14    0.12    0.11    0.19    0.49    0.21    0.14
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9411137313352352
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9404  0.9462  0.9460  0.9388  0.9436  0.9430  0.0030
# Fit time          2.96    2.34    2.26    3.00    2.17    2.54    0.36
# Test time         0.12    0.12    0.12    0.12    0.42    0.18    0.12
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9430119900262424
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9416  0.9458  0.9362  0.9325  0.9385  0.9389  0.0046
# Fit time          0.85    0.79    0.77    0.76    0.81    0.79    0.03
# Test time         0.13    0.13    0.12    0.12    0.34    0.17    0.09
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.9389188757446512
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9524  0.9530  0.9502  0.9518  0.9479  0.9511  0.0019
# Fit time          2.18    1.66    1.50    1.54    1.44    1.66    0.27
# Test time         0.18    0.14    0.16    0.22    0.41    0.22    0.10
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9510653192891516
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9559  0.9591  0.9623  0.9635  0.9631  0.9608  0.0029
# Fit time          2.22    3.02    2.23    2.22    2.12    2.36    0.33
# Test time         0.12    0.12    0.13    0.15    0.12    0.13    0.01
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.01, n_epochs=30
# Mean RMSE: 0.9607650017569392
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9458  0.9411  0.9431  0.9397  0.9543  0.9448  0.0052
# Fit time          0.76    0.84    1.27    0.79    0.78    0.89    0.19
# Test time         0.12    0.19    0.19    0.12    0.37    0.20    0.09
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.9448071590761387
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9638  0.9597  0.9580  0.9571  0.9588  0.9595  0.0023
# Fit time          1.44    1.47    1.46    1.45    1.89    1.54    0.17
# Test time         0.13    0.12    0.13    0.13    0.47    0.20    0.14
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.015, n_epochs=20
# Mean RMSE: 0.9594896917587278
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9623  0.9501  0.9644  0.9588  0.9591  0.9590  0.0049
# Fit time          2.26    2.25    2.17    2.24    3.04    2.39    0.32
# Test time         0.13    0.13    0.11    0.12    0.43    0.18    0.12
# Parameters: n_factors=150, reg_all=0.02, lr_all=0.015, n_epochs=30
# Mean RMSE: 0.9589520431327706
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9397  0.9489  0.9494  0.9501  0.9498  0.9476  0.0039
# Fit time          0.72    0.74    0.75    0.75    0.74    0.74    0.01
# Test time         0.23    0.12    0.12    0.13    0.39    0.20    0.10
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.005, n_epochs=10
# Mean RMSE: 0.947598899602221
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9341  0.9376  0.9251  0.9374  0.9388  0.9346  0.0050
# Fit time          1.47    1.47    2.17    1.44    1.45    1.60    0.28
# Test time         0.12    0.15    0.17    0.12    0.33    0.18    0.08
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.005, n_epochs=20
# Mean RMSE: 0.9345965124404575
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9295  0.9310  0.9328  0.9421  0.9318  0.9334  0.0045
# Fit time          2.16    2.18    2.88    2.09    2.09    2.28    0.30
# Test time         0.12    0.12    0.18    0.12    0.11    0.13    0.03
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.005, n_epochs=30
# Mean RMSE: 0.9334074241548315
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9294  0.9405  0.9344  0.9331  0.9329  0.9341  0.0036
# Fit time          0.73    0.74    0.74    0.75    0.86    0.77    0.05
# Test time         0.12    0.11    0.12    0.11    0.22    0.14    0.04
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.01, n_epochs=10
# Mean RMSE: 0.9340631606004266
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9414  0.9350  0.9424  0.9371  0.9348  0.9381  0.0032
# Fit time          2.08    1.48    1.65    1.53    1.54    1.66    0.22
# Test time         0.15    0.13    0.13    0.34    0.12    0.17    0.08
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.01, n_epochs=20
# Mean RMSE: 0.9381073786261827
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9481  0.9418  0.9376  0.9450  0.9532  0.9451  0.0053
# Fit time          2.64    2.62    2.24    2.52    2.46    2.49    0.14
# Test time         0.18    0.12    0.12    0.13    0.34    0.18    0.09
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.01, n_epochs=30
# Mean RMSE: 0.9451475228305386
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9306  0.9332  0.9339  0.9299  0.9335  0.9322  0.0016
# Fit time          1.18    0.90    0.79    0.81    0.78    0.89    0.15
# Test time         0.19    0.11    0.12    0.13    0.40    0.19    0.11
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.015, n_epochs=10
# Mean RMSE: 0.9322114142350342
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9406  0.9437  0.9490  0.9465  0.9414  0.9442  0.0031
# Fit time          1.49    1.52    1.51    2.14    1.47    1.63    0.26
# Test time         0.16    0.13    0.12    0.18    0.37    0.19    0.09
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.015, n_epochs=20
# Mean RMSE: 0.9442392750504359
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9365  0.9418  0.9362  0.9463  0.9464  0.9414  0.0045
# Fit time          2.23    2.35    2.34    3.05    2.25    2.44    0.31
# Test time         0.12    0.12    0.17    0.14    0.11    0.13    0.02
# Parameters: n_factors=150, reg_all=0.03, lr_all=0.015, n_epochs=30
# Mean RMSE: 0.9414383908627869
